# %%
import xarray as xr
# Open .tif with rasterio engine to get xarray
import rioxarray
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/kim/super-resolution/deepbedmap.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Broger.cs.usyd.edu.au/home/kim/super-resolution/deepbedmap.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import xarray as xr
#       <a href='vscode-notebook-cell://ssh-remote%2Broger.cs.usyd.edu.au/home/kim/super-resolution/deepbedmap.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # Open .tif with rasterio engine to get xarray
# ----> <a href='vscode-notebook-cell://ssh-remote%2Broger.cs.usyd.edu.au/home/kim/super-resolution/deepbedmap.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> import rioxarray
#
# File ~/super-resolution/.conda/lib/python3.8/site-packages/rioxarray/__init__.py:5
#       2 __author__ = """rioxarray Contributors"""
#       3 import importlib.metadata
# ----> 5 import rioxarray.raster_array  # noqa
# ...

# %%
deepbedmap = xr.open_dataset("deepbedmap_dem.tif", engine = "rasterio")
# Out:
# /home/kim/super-resolution/.conda/lib/python3.8/site-packages/xarray/backends/plugins.py:71: RuntimeWarning: Engine 'rasterio' loading failed:
# libiconv.so.2: cannot open shared object file: No such file or directory
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/kim/super-resolution/deepbedmap.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Broger.cs.usyd.edu.au/home/kim/super-resolution/deepbedmap.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> deepbedmap = xr.open_dataset("deepbedmap_dem.tif", engine = "rasterio")
#
# ...

# %%
xds = rioxarray.open_rasterio("/home/kim/data/nsidc/deepbedmap_dem.tif")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/kim/super-resolution/deepbedmap.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Broger.cs.usyd.edu.au/home/kim/super-resolution/deepbedmap.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> xds = rioxarray.open_rasterio("/home/kim/data/nsidc/deepbedmap_dem.tif")
#
# NameError: name 'rioxarray' is not defined
